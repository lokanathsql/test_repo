# %% [markdown]
# <a href="https://colab.research.google.com/github/lokanathsql/test_repo/blob/main/Copy_of_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## import libraries

# %%
from pymongo import MongoClient
import pandas as pd


from pymongo import MongoClient
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/DAS7001_PRAC1/WorldCupMatches.csv')

df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Year    Stage                          Stadium          City HomeTeamName  \
# 0  1982  Group 3                         Camp Nou    Barcelona     Argentina
# 1  1982  Group 1  Estadio Municipal de BalaÔøΩdos         Vigo         Italy
# 2  1982  Group 6            Ramon Sanchez Pizjuan      Seville        Brazil
# 3  1982  Group 1                           Riazor  La CoruÔøΩA          Peru
# 4  1982  Group 3                    Nuevo Estadio        Elche       Hungary
#
#    HomeTeamGoals  AwayTeamGoals  AwayTeamName  Attendance  HalftimeHomeGoals  \
# 0              0              1       Belgium     95000.0                  0
# 1              0              0        Poland     33000.0                  0
# 2              2              1  Soviet Union     68000.0                  0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## connect mongodb atlas

# %%
client = MongoClient(
    "mongodb+srv://lokanathsql_db_user:dYPzPSOgJqvUNzYh@cluster0.qkfrgxt.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
)

db = client["WorldCupDB"]

collection = db["matches"]

print("MongoDB Connected Successfully")
# Out:
# MongoDB Connected Successfully

# %% [markdown]
# ## load csv file

# %%
df = pd.read_csv("/content/drive/MyDrive/DAS7001_PRAC1/WorldCupMatches.csv")

df = df.fillna("")

df.head()
# Out:
#    Year    Stage                          Stadium          City HomeTeamName  \
# 0  1982  Group 3                         Camp Nou    Barcelona     Argentina
# 1  1982  Group 1  Estadio Municipal de BalaÔøΩdos         Vigo         Italy
# 2  1982  Group 6            Ramon Sanchez Pizjuan      Seville        Brazil
# 3  1982  Group 1                           Riazor  La CoruÔøΩA          Peru
# 4  1982  Group 3                    Nuevo Estadio        Elche       Hungary
#
#    HomeTeamGoals  AwayTeamGoals  AwayTeamName Attendance  HalftimeHomeGoals  \
# 0              0              1       Belgium    95000.0                  0
# 1              0              0        Poland    33000.0                  0
# 2              2              1  Soviet Union    68000.0                  0
# 3              0              0      Cameroon    11000.0                  0
# 4             10              1   El Salvador    23000.0                  3
#
# ...

# %% [markdown]
# ## insert csv to mongodb

# %%
data = df.to_dict(orient='records')

collection.insert_many(data)

print("World Cup Dataset Inserted Successfully")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipykernel_28726/1797766272.py in <cell line: 0>()
#       1 data = df.to_dict(orient='records')
#       2
# ----> 3 collection.insert_many(data)
#       4
#       5 print("World Cup Dataset Inserted Successfully")
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     972         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
# ...

# %% [markdown]
# ## Insert Additional Documents with Missing Fields

# %%
extra_docs = [

    {
        "Year": 2026,
        "Stage": "Quarter-finals",
        "HomeTeamName": "India",
        "AwayTeamName": "Japan"
    },

    {
        "Year": 2026,
        "Stage": "Semi-finals",
        "HomeTeamName": "Brazil",
        "AwayTeamName": "Germany",
        "HomeTeamGoals": 2
    },

    {
        "Year": 2026,
        "Stage": "Final",
        "HomeTeamName": "Argentina",
        "AwayTeamName": "France"
    },

    {
        "Year": 2026,
        "Stage": "Group Stage",
        "HomeTeamName": "Spain",
        "AwayTeamName": "Portugal"
    },

    {
        "Year": 2026,
        "Stage": "Round of 16",
        "HomeTeamName": "England",
        "AwayTeamName": "Italy"
    }
]

collection.insert_many(extra_docs)

print("Extra Documents Inserted Successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28726/3927345399.py in <cell line: 0>()
#      38 ]
#      39
# ---> 40 collection.insert_many(extra_docs)
#      41
#      42 print("Extra Documents Inserted Successfully")
#
# NameError: name 'collection' is not defined

# %% [markdown]
# ## QUERY 1 — Display Quarter Final Matches

# %%
for match in collection.find({"Stage": "Quarter-finals"}):
    print(match)

# %% [markdown]
# ## QUERY 2 — Display Selected Columns

# %%
for match in collection.find(
    {},
    {
        "Year": 1,
        "Stage": 1,
        "HomeTeamName": 1,
        "AwayTeamName": 1,
        "_id": 0
    }
):
    print(match)

# %% [markdown]
# ## QUERY 3 — Display Final Matches

# %%
for match in collection.find({"Stage": "Final"}):
    print(match)

# %% [markdown]
# ## QUERY 4 — Delete Documents Where HomeTeamGoals = 0

# %%
result = collection.delete_many({"HomeTeamGoals": 0})

print(result.deleted_count, "documents deleted")

# %% [markdown]
# ## QUERY 5 — Update RoundID

# %%
result = collection.update_many(
    {"RoundID": 308},
    {"$set": {"RoundID": 30800}}
)

print(result.modified_count, "documents updated")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28726/2822386030.py in <cell line: 0>()
# ----> 1 result = collection.update_many(
#       2     {"RoundID": 308},
#       3     {"$set": {"RoundID": 30800}}
#       4 )
#       5
#
# NameError: name 'collection' is not defined

# %% [markdown]
# ## QUERY 6 — Delete Referee Names Starting with S

# %%
result = collection.delete_many(
    {"Referee": {"$regex": "^S"}}
)

print(result.deleted_count, "documents deleted")
